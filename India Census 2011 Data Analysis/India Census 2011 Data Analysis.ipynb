# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\LENOVO\Desktop\datasets\6. India Census 2011.csv")
df
# Out:
#      District_code                   State_name              District_name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population    Male  Female  Literate  Workers  Male_Workers  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   District_code         640 non-null    int64
#  1   State_name            640 non-null    object
#  2   District_name         640 non-null    object
#  3   Population            640 non-null    int64
#  4   Male                  640 non-null    int64
#  5   Female                640 non-null    int64
#  6   Literate              640 non-null    int64
#  7   Workers               640 non-null    int64
#  8   Male_Workers          640 non-null    int64
#  9   Female_Workers        640 non-null    int64
#  10  Cultivator_Workers    640 non-null    int64
#  11  Agricultural_Workers  640 non-null    int64
#  12  Household_Workers     640 non-null    int64
#  13  Hindus                640 non-null    int64
#  14  Muslims               640 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# District_code           0
# State_name              0
# District_name           0
# Population              0
# Male                    0
# Female                  0
# Literate                0
# Workers                 0
# Male_Workers            0
# Female_Workers          0
# Cultivator_Workers      0
# Agricultural_Workers    0
# Household_Workers       0
# Hindus                  0
# Muslims                 0
# Christians              0
# Sikhs                   0
# Buddhists               0
# Jains                   0
# Secondary_Education     0
# Higher_Education        0
# Graduate_Education      0
# Age_Group_0_29          0
# Age_Group_30_49         0
# Age_Group_50            0
# dtype: int64

# %% [markdown]
# <h3>How will you hide the indexes of the dataframe</h3>

# %%
df.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
df.head().style.hide(axis = 'index')   #df.style.hide(axis = 'index')   ya columns bhi likh sakte toh sirf index bachega baaki saare columns hide ho jayenge
# Out:
# <style type="text/css">
# </style>
# <table id="T_89222">
#   <thead>
#     <tr>
#       <th id="T_89222_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_89222_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_89222_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_89222_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_89222_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_89222_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_89222_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_89222_level0_col7" class="col_heading level0 col7" >Workers</th>
#       <th id="T_89222_level0_col8" class="col_heading level0 col8" >Male_Workers</th>
#       <th id="T_89222_level0_col9" class="col_heading level0 col9" >Female_Workers</th>
# ...

# %% [markdown]
# <h3>How can we set the caption/heading on the dataframe.</h3>

# %%
df.head().style.set_caption("India Census 2011 Dataset")
# Out:
# <style type="text/css">
# </style>
# <table id="T_a72d1">
#   <caption>India Census 2011 Dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a72d1_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_a72d1_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_a72d1_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_a72d1_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_a72d1_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_a72d1_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_a72d1_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_a72d1_level0_col7" class="col_heading level0 col7" >Workers</th>
#       <th id="T_a72d1_level0_col8" class="col_heading level0 col8" >Male_Workers</th>
# ...

# %% [markdown]
# <h3>Show the records related with the districts - New Delhi, lucknow , jaipur</h3>

# %%
df[df['District_name'].isin(['New Delhi' , 'Lucknow', 'Jaipur'])]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062
# 109            110      RAJASTHAN        Jaipur     6626178  3468507  3157671
# 156            157  UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 109   4300965  2464893       1714947          749946  ...       12708  18782
# 156   3127260  1542806       1226399          316407  ...       20493  23883
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 109       1020  81079               659389            455527
# 156       3877   4975               428121            378742
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %% [markdown]
# <h3>Calculate state wise <br>
# 1. Total number of population<br>
# 2. total no of population with different religions.</h3>

# %%
df.groupby('State_name').Population.sum().sort_values(ascending = False)
# Out:
# State_name
# UTTAR PRADESH                  199812341
# MAHARASHTRA                    112374333
# BIHAR                          104099452
# WEST BENGAL                     91276115
# ANDHRA PRADESH                  84580777
# MADHYA PRADESH                  72626809
# TAMIL NADU                      72147030
# RAJASTHAN                       68548437
# KARNATAKA                       61095297
# GUJARAT                         60439692
# ORISSA                          41974218
# KERALA                          33406061
# JHARKHAND                       32988134
# ASSAM                           31205576
# PUNJAB                          27743338
# CHHATTISGARH                    25545198
# HARYANA                         25351462
# NCT OF DELHI                    16787941
# JAMMU AND KASHMIR               12541302
# UTTARAKHAND                     10086292
# HIMACHAL PRADESH                 6864602
# TRIPURA                          3673917
# ...

# %%
df.columns
# Out:
# Index(['District_code', 'State_name', 'District_name', 'Population', 'Male',
#        'Female', 'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
df.groupby('State_name')[['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains']].sum().sort_values(by = 'Sikhs' , ascending = False)
# Out:
#                                 Hindus   Muslims  Christians     Sikhs  \
# State_name
# PUNJAB                        10678138    535489      348230  16004754
# HARYANA                       22171128   1781342       50353   1243752
# RAJASTHAN                     60657103   6215377       96430    872930
# UTTAR PRADESH                159312654  38483967      356448    643500
# NCT OF DELHI                  13712100   2158684      146093    570581
# UTTARAKHAND                    8368636   1406825       37781    236340
# JAMMU AND KASHMIR              3566674   8567485       35631    234848
# MAHARASHTRA                   89703057  12971152     1080073    223247
# MADHYA PRADESH                66007121   4774695      213282    151412
# CHANDIGARH                      852574     51447        8720    138329
# HIMACHAL PRADESH               6532765    149881       12646     79896
# JHARKHAND                     22376051   4793994     1418608     71422
# ...

# %% [markdown]
# <h3>how many male workers were there in Maharashtra state?</h3>

# %%
df.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
df[df['State_name'] == 'MAHARASHTRA']['Male_Workers'].sum()
# Out:
# np.int64(32616875)

# %% [markdown]
# <h3>How to set a column as index of the dataframe</h3>

# %%
df.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
df.set_index('District_code')
# Out:
#                                 State_name              District_name  \
# District_code
# 1                        JAMMU AND KASHMIR                    Kupwara
# 2                        JAMMU AND KASHMIR                     Badgam
# 3                        JAMMU AND KASHMIR                Leh(Ladakh)
# 4                        JAMMU AND KASHMIR                     Kargil
# 5                        JAMMU AND KASHMIR                      Punch
# ...                                    ...                        ...
# 636                            PONDICHERRY                       Mahe
# 637                            PONDICHERRY                   Karaikal
# 638            ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 639            ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 640            ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#                Population    Male  Female  Literate  Workers  Male_Workers  \
# District_code
# ...

# %% [markdown]
# <h3>Add a suffix to the column names.<br>
# Add a prefix to the column names.</h3>

# %%
df.add_suffix("_willBeOnBack")
# Out:
#      District_code_willBeOnBack      State_name_willBeOnBack  \
# 0                             1            JAMMU AND KASHMIR
# 1                             2            JAMMU AND KASHMIR
# 2                             3            JAMMU AND KASHMIR
# 3                             4            JAMMU AND KASHMIR
# 4                             5            JAMMU AND KASHMIR
# ..                          ...                          ...
# 635                         636                  PONDICHERRY
# 636                         637                  PONDICHERRY
# 637                         638  ANDAMAN AND NICOBAR ISLANDS
# 638                         639  ANDAMAN AND NICOBAR ISLANDS
# 639                         640  ANDAMAN AND NICOBAR ISLANDS
#
#     District_name_willBeOnBack  Population_willBeOnBack  Male_willBeOnBack  \
# 0                      Kupwara                   870354             474190
# 1                       Badgam                   753745             398041
# ...

# %%
df.add_prefix("willBeOnFront_")
# Out:
#      willBeOnFront_District_code     willBeOnFront_State_name  \
# 0                              1            JAMMU AND KASHMIR
# 1                              2            JAMMU AND KASHMIR
# 2                              3            JAMMU AND KASHMIR
# 3                              4            JAMMU AND KASHMIR
# 4                              5            JAMMU AND KASHMIR
# ..                           ...                          ...
# 635                          636                  PONDICHERRY
# 636                          637                  PONDICHERRY
# 637                          638  ANDAMAN AND NICOBAR ISLANDS
# 638                          639  ANDAMAN AND NICOBAR ISLANDS
# 639                          640  ANDAMAN AND NICOBAR ISLANDS
#
#     willBeOnFront_District_name  willBeOnFront_Population  willBeOnFront_Male  \
# 0                       Kupwara                    870354              474190
# ...
